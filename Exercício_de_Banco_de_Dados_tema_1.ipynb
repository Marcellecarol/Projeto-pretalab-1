# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcellecarol/Projeto-pretalab-1/blob/main/Exerc%C3%ADcio_de_Banco_de_Dados_tema_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![pretalab.png](data:image/png;base64,...)

# %% [markdown]
# #Bem Vinde ao Exercício de Banco de Dados do Tema - 1
#
#
# O exercício será indívidual que terá 8 perguntas, a cada consulta que você fizer para responder terá que ter comentário explicando motivo da consulta e de como elaborou.
# **Explicação:** Esta consulta soma os focos de queimadas por estado no ano de 2023, ordenando para encontrar o estado com mais queimadas.
#
# Tendo essa explicação você já tem direcionamento de como responder cada pergunta e fazer a explicação dela.
#
# Você terá três escolhas de tema relacionado ao Análise de emissões de carbono e meio ambiente. Não é para pegar os 3, para escolher um deles para responder as 8 perguntas.
#
# Terá que subir no Github e terá todo comando de como subir esse trabalho no github, mas lembrando de fazer o Readme explicando sobre o projeto do que você no readme. Na parte Final vai ter explicação de como elaborar ele pra escrever.
#
# 1. **O link para primeiro tema é Banco de Dados de Queimadas:** [Dados](https://basedosdados.org/dataset/f06f3cdc-b539-409b-b311-1ff8878fb8d9?table=a3696dc2-4dd1-4f7e-9769-6aa16a1556b8).
#
# 2. **O link para segundo tema é Desmatamento PRODES:** [Dados](https://basedosdados.org/dataset/e5c87240-ecce-4856-97c5-e6b84984bf42?table=d7a76d45-c363-4494-826d-1580e997ebf0).
#
# 3. **O link para terceiro tema é Emissões de gases de efeito estufa no Brasil:**
# [Dados](https://basedosdados.org/dataset/e5c87240-ecce-4856-97c5-e6b84984bf42?table=d7a76d45-c363-4494-826d-1580e997ebf0).
#
#
# Você pode colocar as perguntas na BigQuery, se você quiser colocar imagem como print para cada pergunta dentro do colab fica ao seu critério, importante e você subir tanto essa colab no github e subir a consulta da BigQuery também. Fazer da mesma forma que você aprendeu em aula. Caso tenha faltado a aula chame der um sinal para a a gente explicar como faz.

# %% [markdown]
# ALUNA: MARCELLE CAROLINA CAETANO COELHO

# %% [markdown]
# # **Tema Branco de dados de Queimadas**

# %% [markdown]
# ## Pergunta 1: Qual estado teve o maior número de focos de queimadas em 2023?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 2: Qual o ano com mais queimadas nos últimos 5 anos no Brasil?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 3: Qual foi o bioma mais afetado pelas queimadas em 2022?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 5: Qual foi a média de focos de queimadas por estado no Brasil em 2020?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 6: Qual município teve mais focos de queimadas em 2021 no estado do Mata Atlântica?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 7: Qual a evolução anual do número de queimadas no Cerrado entre 2015 e 2023?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 8: Quantos focos de queimadas foram registrados por bioma no ano de 2005 no banco de dados do INPE?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
